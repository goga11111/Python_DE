# %%
import json

# %%
file_path = "d:\DOC\Tanfolyam\DataEngineer\Python_DE\Homeworks - Module II\json_handling\spotify_playlist.json"

with open(file_path, "r") as json_file:
    data = json.load(json_file)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\goga\AppData\Local\Temp\ipykernel_2468\3889700552.py:1: SyntaxWarning: invalid escape sequence '\D'
#   file_path = "d:\DOC\Tanfolyam\DataEngineer\Python_DE\Homeworks - Module II\json_handling\spotify_playlist.json"

# %%
data["contents"]["items"][31]["name"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data["contents"]["items"][31]["name"]
#
# NameError: name 'data' is not defined

# %%
for track in data["contents"]["items"]:
    print(track["playCount"])
    print(track["name"])
    print()
# Out:
# 30569756
# 3D (feat. Jack Harlow)
#
# 825957263
# Seven (feat. Latto) (Explicit Ver.)
#
# 356592711
# Paint The Town Red
#
# 74959220
# greedy
#
# 110198354
# Strangers
#
# 1151554203
# Cruel Summer
#
# 196461114
# QLONA
#
# 470247058
# LALA
#
# 24413575
# Si No Estás
#
# 432858794
# vampire
#
# 29712924
# UN PREVIEW
#
# 341014134
# fukumean
#
# 1483444237
# I Wanna Be Yours
#
# 344168581
# What Was I Made For? [From The Motion Picture "Barbie"]
#
# 282928846
# LADY GAGA
#
# 326179824
# Columbia
#
# 412675720
# Dance The Night - From Barbie The Album
#
# 598705196
# Daylight
#
# 108629879
# Prada
#
# 2708288511
# As It Was
#
# 2714056733
# Starboy
#
# 1354228715
# Kill Bill
#
# 77004685
# Que Onda
#
# 89028576
# Chaleya
#
# 169009521
# bad idea right?
#
# 59731033
# Según Quién
#
# 33302347
# My Love Mine All Mine
#
# 97820711
# I Remember Everything (feat. Kacey Musgraves)
#
# 1514020374
# Blank Space
#
# 232720041
# Primera Cita
#
# 946521797
# Style
#
# 1794007610
# Die For You
#
# ...
