# %%
import json
from datetime import datetime
from dateutil.relativedelta import relativedelta
#import dateutil
import os
import pandas as pd
import requests

# %%
url = "https://data.cityofchicago.org/resource/wrvz-psew.json?trip_id=00000019ef3c0b419a9e6b1843b83530b79627a4"

#headers = {"X-App-Token": "api_key"}
headers = {"X-App-Token": os.environ.get("CHICAGO_API_TOKEN")}

response = requests.get(url, headers)

data = response.json()

# %%
data
# Out:
# [{'trip_id': '00000019ef3c0b419a9e6b1843b83530b79627a4',
#   'taxi_id': 'bda916a4fa3043f7e827751d9d8cada1239d574beb206d846e1d7d425b658d56aa23393b6866d3a19f9dca6c32d3a8642f14361c5d58dccebd42e398fee18e94',
#   'trip_start_timestamp': '2023-12-11T16:15:00.000',
#   'trip_end_timestamp': '2023-12-11T17:00:00.000',
#   'trip_seconds': '2572',
#   'trip_miles': '17.56',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081700',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.75',
#   'tips': '12.06',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '60.31',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892042136',
#   'dropoff_centroid_longitude': '-87.63186395',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6318639497, 41.8920421365]}}]

# %%
#url = f"https://data.cityofchicago.org/resource/wrvz-psew.json?$where=trip_start_timestamp >= '2023-08-05T00:00::00' AND trip_start_timestamp <= '2023-08-05T23:59::59'&$limit=30000"
current_datetime = datetime.now() - relativedelta(months=2)
formatted_datetime = current_datetime.strftime("%Y-%m-%d")

url = (
    f"https://data.cityofchicago.org/resource/ajtu-isnz.json?"
    f"$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' "
    f"AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"
)
response = requests.get(url)

data = response.json()

# %%
len(data)
# Out:
# 20381

# %%
data
# Out:
# [{'trip_id': '4566e1730a2afde1683227b07ffb90efaa28a87f',
#   'taxi_id': '57fa54b44d1e25d82c1de3200158c2475a894490b1c32c4b5356e694a3d15f896fc0ffebb9422cc1875ebd24a578bd9e80d7143e444d36e8ec39f08f19bad982',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1361',
#   'trip_miles': '6.65',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '6',
#   'fare': '15.56',
#   'tips': '4.18',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '19.74',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '3bffd046795abcf2781f9cfa3511d8b4a0806ef5',
#   'taxi_id': 'abf6ffe94144e712e0efd817d27e8b918121efc45a7e4eba53c63968dad12e0dbc466541eb5ae504956242e437cac686b2754669b5eaadeb3bbdebeb694e8d0f',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '5',
#   'trip_miles': '0',
#   'pickup_community_area': '14',
#   'dropoff_community_area': '14',
#   'fare': '55',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '55.5',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.968069',
#   'pickup_centroid_longitude': '-87.721559063',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7215590627, 41.968069]},
#   'dropoff_centroid_latitude': '41.968069',
#   'dropoff_centroid_longitude': '-87.721559063',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7215590627, 41.968069]}},
#  {'trip_id': '3b6a1a048a4cbc90a7e8093f6bc6a27b204184a0',
#   'taxi_id': 'dff8b2296e1abd3c3470a2f0765b3f385f9a53c8df1cc314e899a81be2cfb6f52c61af660e6434c35e2c1a4ab2eeb004ab0027826471be4fff9a4648ef51e7a0',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '818',
#   'trip_miles': '2.38',
#   'pickup_census_tract': '17031280100',
#   'dropoff_census_tract': '17031071500',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '7',
#   'fare': '11.17',
#   'tips': '3.05',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '14.22',
#   'payment_type': 'Mobile',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.885300022',
#   'pickup_centroid_longitude': '-87.642808466',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6428084655, 41.8853000224]},
#   'dropoff_centroid_latitude': '41.914616286',
#   'dropoff_centroid_longitude': '-87.631717366',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6317173661, 41.9146162864]}},
#  {'trip_id': '3b3c014a9495347d783a29ece3478223952c0087',
#   'taxi_id': '6fa0364cac8d604e8a7613c08fdcbe5bfa05e361d4a7585de8caaa7b5f12b0c5b3c3a00fe5e1bfe58c3341d7aa3e0c4ff23cbdf4375dd3e55f20b643e85ab683',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1174',
#   'trip_miles': '0',
#   'pickup_community_area': '33',
#   'dropoff_community_area': '6',
#   'fare': '21.23',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '21.23',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.857183858',
#   'pickup_centroid_longitude': '-87.620334624',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6203346241, 41.8571838585]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '384c59c71501ab18a028199ef2da431ab2dd7b05',
#   'taxi_id': 'bc71b5d2cb8320a69947adef34a809194621917747c14bae6b3f3c163c59f57102f65a33c3d0598ff30d468a756c170931cea53d236f0e0bcff8a5b858351730',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '720',
#   'trip_miles': '1.3',
#   'pickup_census_tract': '17031281900',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '8.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '8.25',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.879255084',
#   'pickup_centroid_longitude': '-87.642648998',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.642648998, 41.8792550844]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': '382077cd2cc5451104818164306e5034b5aae780',
#   'taxi_id': '35fb25430002f0fd17160ae575a0c43e253d3c8d1a9794adb36b94900a117ddf0ef308234642cdcb2defa87b66f28a1ce8810c92665fc4d40e704bb6524e86cb',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1348',
#   'trip_miles': '15.35',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031804603',
#   'pickup_community_area': '76',
#   'fare': '38.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '21',
#   'trip_total': '59.5',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': '37c426c253b7712603851ef4aa39a0219ea850d6',
#   'taxi_id': '018e2fc4d3e35a1f76f3221f8ecf824591aea4e6e7e05fb330b4a5f29349c5ad53a1906a0ba96738df71c18d9ca8f54bd2aa49527b16644296b4c344d00aec47',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '238',
#   'trip_miles': '0.63',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '7',
#   'fare': '5.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1.5',
#   'trip_total': '6.75',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '37190e13dbf3ca2f8d9e02a49a8ebcaf534c5d88',
#   'taxi_id': '1e17dd9f6bce9b805ec3f6c6b510caa5a64e4b67e9f3b79fa7ca1781d0c7970d6b754f429a79075c22e353586076b9f2f6856e8f98b31f5022751d7eb321069b',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '45',
#   'trip_miles': '0.03',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '28',
#   'fare': '3.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '3.25',
#   'payment_type': 'Cash',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '36205b33e247f6420f2b7a06e34d968e24a61432',
#   'taxi_id': '3577d72a8bf30406c1346a5e178b7f3a0ce8e1f966f59afa6b9acfd4668b779e82f3766dd3b426278a666a18a9ae5d159070e7821e06c0c00ed390eca863e001',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '960',
#   'trip_miles': '2.5',
#   'pickup_census_tract': '17031081500',
#   'dropoff_census_tract': '17031071500',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '7',
#   'fare': '10.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '10.75',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.892507781',
#   'pickup_centroid_longitude': '-87.626214906',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]},
#   'dropoff_centroid_latitude': '41.914616286',
#   'dropoff_centroid_longitude': '-87.631717366',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6317173661, 41.9146162864]}},
#  {'trip_id': '3319bed400c752ee49a754ac5ebb2b41de08f743',
#   'taxi_id': 'c0591d33660deb744cef729db6457d5a0924498c9ed3bb80b0160d6bdec6de41d28db4d9de45475ad8257687670f437406d85c13fe34381fb80c206745ea7dc0',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '875',
#   'trip_miles': '2.89',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '7',
#   'fare': '10.9',
#   'tips': '1.49',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12.39',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '30df5b05c1556c17a04056bd431921fb7f8e5c67',
#   'taxi_id': '1b7aef0344f45914e7942efad05553934fe222c880a1cb19de79fbf7c4c42213cb82f74d26f02a4ef8f42bdba220392fef9e31be732048be89111a59fedafbf4',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '2011',
#   'trip_miles': '13.9',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '22',
#   'fare': '36',
#   'tips': '8.3',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '49.8',
#   'payment_type': 'Credit Card',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': '2dcc7bad7e1ea749bfd2e49c3895e0ecd7d941a7',
#   'taxi_id': '16a529a73f019759aa8f1b563ab8511b26a91d656591885584404613ef60bbfaeebb669ddd12afa282f8eacd3e71e048846a9a71f7097eaec4fb06803f445d29',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '1020',
#   'trip_miles': '1.9',
#   'pickup_census_tract': '17031833000',
#   'dropoff_census_tract': '17031081403',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '10.75',
#   'tips': '3',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '13.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.88528132',
#   'pickup_centroid_longitude': '-87.6572332',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]},
#   'dropoff_centroid_latitude': '41.890922026',
#   'dropoff_centroid_longitude': '-87.618868355',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6188683546, 41.8909220259]}},
#  {'trip_id': '2ca3ae2b526277302c5b514b2668d61438ef4df1',
#   'taxi_id': '3edf5aaee7cd5378f854cca9e574820e57badb93344e0c367b70b3e39f3efb4484a3da00e6553a0c711580349369dab3969adb9845c6fd8bc63cce362a80da8f',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:45:00.000',
#   'trip_seconds': '2846',
#   'trip_miles': '6.24',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '24',
#   'fare': '26.75',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '32.75',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': '2ba5f6d984c9da555b919bdb82103aa0602f281a',
#   'taxi_id': 'ee8c4cb9eb10dcb967d64305ca79a9068dbf0b5b12f3ec2968e4eaf4d743ed7e8472c8f85c08f0b789dcbcce33f62da5a281c4c741fdc5764b0bb602c332bfef',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '780',
#   'trip_miles': '11.96',
#   'pickup_community_area': '34',
#   'dropoff_community_area': '75',
#   'fare': '30.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30.25',
#   'payment_type': 'Prcard',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.842076117',
#   'pickup_centroid_longitude': '-87.633973422',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6339734222, 41.8420761168]},
#   'dropoff_centroid_latitude': '41.689729914',
#   'dropoff_centroid_longitude': '-87.669054403',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6690544032, 41.6897299145]}},
#  {'trip_id': '29cd7d25e553a94c75b644f6a04643d3f7307561',
#   'taxi_id': '6544c8051894de482dd3253d911c3e3d713b43beb93de2f63eece4cc682a8fb12516e8a4b05e3f0bb77602be3ed3686299d1b8b0c3ece2ab2d183119053ad5b8',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '987',
#   'trip_miles': '11.03',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031770400',
#   'pickup_community_area': '76',
#   'fare': '28.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '6',
#   'trip_total': '34.75',
#   'payment_type': 'Cash',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': '29745de6901a9a663d100d00375405902cbab08e',
#   'taxi_id': '214fcdd082c941bd6273631b0ff3cedc4bd5307f719e731b7c2c87f3fc956631333f8deefb6093275c5e628b20d631651e835f4eb4d1387498be140030749f32',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '440',
#   'trip_miles': '1.97',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '8.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '13.5',
#   'payment_type': 'Cash',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '28878bcc63f1bdf0b0b3553705fdd765aa57220b',
#   'taxi_id': '63bd96dd48d993d6de99e296a9c9e425551d2481df12cf5cd29305ffefaf25a4baed5beed0c160f6d19b76d371b7ebbff776f7f5678c24f4ffbc3b987c226145',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '780',
#   'trip_miles': '7.7',
#   'pickup_community_area': '76',
#   'fare': '21',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '31',
#   'trip_total': '57',
#   'payment_type': 'Credit Card',
#   'company': 'Choice Taxi Association',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '26f83ec8542a725ae819ab6c4977c82b86519cd5',
#   'taxi_id': '07f3ce687dce8fa4518b83cd63bfbfb0383339fd188b5b6b22f4d33d0dbc445b56eabe1b74a1e06ab4cd5533bfdb89f0322934d5a2cc4fa67a4eb383ffd743ec',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '1320',
#   'trip_miles': '11.4',
#   'pickup_community_area': '50',
#   'dropoff_community_area': '38',
#   'fare': '30',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30',
#   'payment_type': 'Unknown',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.706125752',
#   'pickup_centroid_longitude': '-87.598255838',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5982558383, 41.7061257523]},
#   'dropoff_centroid_latitude': '41.812948939',
#   'dropoff_centroid_longitude': '-87.617859676',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6178596758, 41.8129489392]}},
#  {'trip_id': '1f93a5ba08174db568424d4b629148212ecc251e',
#   'taxi_id': 'f6ea1f58e87fd583890861ab62c8f06f47dd09f494e80176213469293049fbff7f78ed805edba4b977aec3ecd2c6ff4130ad4ad05caf0093103932a4bd4328b6',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '0',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031081700',
#   'pickup_community_area': '8',
#   'fare': '0',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '0',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.892042136',
#   'pickup_centroid_longitude': '-87.63186395',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6318639497, 41.8920421365]}},
#  {'trip_id': '1f11342cec528c2671359c1d3332e2bb5928a9f5',
#   'taxi_id': 'cce8c54f19d692acc5dd45d391a8bb964d15af67f314d1ac81e0597f105a70ad12935afa9487766eef90a6f8f0f3d09e6a8877e99b01d21035a05b4a16e985c4',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '420',
#   'trip_miles': '0.9',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '6.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '2',
#   'trip_total': '8.25',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '1d207e1c88be12a85568825af04506bea43d03ae',
#   'taxi_id': 'f45c4bfa9d6c445eb03ab69093f7ec1e9cdecef83cb2cedd0d739143caa40e15d2e8be5e3df63c6304151e5d9904fad85ae4acffb2b6e20f886eb55438fce790',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '715',
#   'trip_miles': '1.75',
#   'pickup_census_tract': '17031280100',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '32',
#   'fare': '10',
#   'tips': '3.85',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '14.85',
#   'payment_type': 'Mobile',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.885300022',
#   'pickup_centroid_longitude': '-87.642808466',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6428084655, 41.8853000224]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '18ecc06bb10729c168cd3f7812ff2144696ed9f4',
#   'taxi_id': '4972764cee12598f449342da6c1c3f3686f6e800184eba41cbbf980d465e1f7c56f5b42e786c1cf4831ed964de0a76de17ba9c18123a7ecf89c36b74697b6b6f',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1900',
#   'trip_miles': '17.63',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '44.5',
#   'tips': '7.35',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '56.35',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': '14035dba609cd63459d8ad6078ea2c891cd8f62a',
#   'taxi_id': '52e8915b8a7b8851b341adb6797c3652a198b772561e9e9888d9963de61b796f60653ebdd06f44aa2fad304efb0a53160d6210b2a26fcc64b21932db0d658e32',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '975',
#   'trip_miles': '0',
#   'pickup_community_area': '22',
#   'dropoff_community_area': '22',
#   'fare': '14.12',
#   'tips': '1.9',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '16.02',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.92276062',
#   'pickup_centroid_longitude': '-87.699155343',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': '0d70cc36fea78de947d4fe662d616b3a69621f44',
#   'taxi_id': 'eed4cbab8d3be11fc5fcff8f92b3ba140f63602f2760446756572fc4262d89af90bd665c89604918253358364f34ae32113be46209e794e28390e6cca1a87768',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '905',
#   'trip_miles': '2.28',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '60',
#   'fare': '35',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '35',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.836150155',
#   'dropoff_centroid_longitude': '-87.648787952',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6487879519, 41.8361501547]}},
#  {'trip_id': '0c43d2240e4686aae49d32d8212e080bf5809a17',
#   'taxi_id': 'db6676bf734c043869e21f37386c67f0fca7bf488d13b62e4970132bcb27a96e472b7bb75dd659ce92c0e9e6477abf08c57b0ed3c484af8711123d54422bc125',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '1080',
#   'trip_miles': '0',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '32',
#   'fare': '33',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '33',
#   'payment_type': 'Cash',
#   'company': 'Choice Taxi Association',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '0b0cb343ac2ae0648cc64c821340997c34d47776',
#   'taxi_id': '8b8d35663133904892cc1e87911f55ed0bdf9a9bd1093c97025869a02f151c9ac0e089ac00a581281e172b00ec459830089882f5f4261ea514929a5a6ad0d169',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '953',
#   'trip_miles': '3.24',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '6',
#   'fare': '13.46',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '14.46',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': '09006eba20f12649df303ae967c4fdf3327b7915',
#   'taxi_id': '3ce4fc90cbd3376aa82949f32cbae53a84afa8e88548861f53129929875c84d2478b77340d2d9d5738cd69ad23b7a012a3cc6364084345a44d1d89bd94acda3f',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '305',
#   'trip_miles': '1.12',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '10',
#   'tips': '2.87',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12.87',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '076340d40178c9de43c08cad5d565273e6a5e68a',
#   'taxi_id': 'bb4e75d3065311c33024a434640731c43fd2cf9e4482eb9e17cbf9f0ff0ed005455ffe22797df66b7467489a738e7be52c5983e16615b31c7c1d6af3ee0eb965',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '720',
#   'trip_miles': '1.2',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '32',
#   'fare': '8',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '9',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '06574c4f4cf48bf07acc2cfb49fbada4d95b63c2',
#   'taxi_id': '88ecf448361fbe40dae4862335a2b689529bfb66bf2fb4899102a790e9ec5e79251dd5db8496a9e47d9ce41a742c527d33fac878343d80e3baac2b51b900f9a1',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '1440',
#   'trip_miles': '7.6',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '3',
#   'fare': '23',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '23',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.96581197',
#   'dropoff_centroid_longitude': '-87.655878786',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]}},
#  {'trip_id': '02ccd13b2054ff34e51cdae1ae744ed86d230734',
#   'taxi_id': '6b50c5bb5761c3cb4853a8ca215dee42e63e922c7ebb0ce74cd52a2b3076c37ed38a45d19077a78a0bd19fe39c5e2efce4ed1ad13af2f2b67cbdb049839aae41',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '660',
#   'trip_miles': '1.3',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '28',
#   'fare': '7.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '8.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': 'ffacce7288ba1eda8da2494d4bbb3be4e8d79512',
#   'taxi_id': 'e4af2b2e69721524f8a3c3130f9a0a185666892a933040a6dbb8df75ba4a0d51c09f3db3babd9fae1cb0d6202421caf5ae8be505490e7e9fb715214349daddda',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '716',
#   'trip_miles': '2.21',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '9.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1.5',
#   'trip_total': '11.25',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'da4c51c49e12e0a572c9479066313cbb3aac0eec',
#   'taxi_id': 'ca30b49aab641fe71294a9b03b991b968c7f3e47e1169140822a128e8a2519736f5b12b38680410ecc3a222a14cd4a610b462a88eecfe74a3084eabf8b794565',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1683',
#   'trip_miles': '18.16',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031839100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '45',
#   'tips': '7.58',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '58.08',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.880994471',
#   'dropoff_centroid_longitude': '-87.632746489',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]}},
#  {'trip_id': 'd66da92ddc0f40e74d96b0fbb62b7d64466c14cb',
#   'taxi_id': 'b41e8c8124d8d600a4db8b7c176c2956756d378c749cb11c0a8e2c326a4c1cd83cac353869b657c398c9abc2c9d1d4c760905cfd5189595282dbfbe2fb0ce482',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '0',
#   'trip_miles': '0',
#   'pickup_community_area': '7',
#   'dropoff_community_area': '7',
#   'fare': '45',
#   'tips': '9.05',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '54.05',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.922686284',
#   'pickup_centroid_longitude': '-87.649488729',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': 'ced8f39c218950d5a9861975961c5fe8caf3cc05',
#   'taxi_id': 'b2faa1d3e1b91bb0e84ca332617afa61667a5e8d8bc09867a441a8fba87bc8b82c0e3d0be873b2a142f0fdcc94a003101cc022009d68c05d8c0a6651b8d980fa',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '693',
#   'trip_miles': '1.94',
#   'pickup_census_tract': '17031833000',
#   'dropoff_census_tract': '17031081403',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '9.25',
#   'tips': '3',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '13.75',
#   'payment_type': 'Credit Card',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.88528132',
#   'pickup_centroid_longitude': '-87.6572332',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]},
#   'dropoff_centroid_latitude': '41.890922026',
#   'dropoff_centroid_longitude': '-87.618868355',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6188683546, 41.8909220259]}},
#  {'trip_id': 'ca77031eeb855d328e8af0f932876249e3ec2add',
#   'taxi_id': 'd94ecbd1167693d3854fac6b4d884eae97f0ba5f43e5a6a224a21bdda396edb7aab1646024ec87b937bf8959b3ae6f3c07fb93fea7a218fad5e989bc971a607e',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '480',
#   'trip_miles': '4.3',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '12.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '16.75',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.980264315',
#   'dropoff_centroid_longitude': '-87.913624596',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'c664e0fabb35e42aa03de5027cdb7f274d9e51f2',
#   'taxi_id': 'bab73d82a115cb08f1bcd17caebbb2581e3a6f29d92adc859f44304acc357c859fb025673c5b9d6379ab41c191ca7b09fa7275a1ee66bf2e3f55215c1d838430',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '300',
#   'trip_miles': '0',
#   'pickup_community_area': '6',
#   'dropoff_community_area': '7',
#   'fare': '7',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '7',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.944226601',
#   'pickup_centroid_longitude': '-87.655998182',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': 'c2fde5148086156073f5c362100a293c7ffef7ae',
#   'taxi_id': 'c84c28526a906ef1ad0ea7dc570f97949ecf92dfe156cba9a18ba57e15d5d09922a6ce106ef96217f140de7fa0b718ebecfd23126d409075524c429c946e0f44',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1937',
#   'trip_miles': '16.28',
#   'pickup_community_area': '76',
#   'fare': '41.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '8',
#   'trip_total': '49.5',
#   'payment_type': 'Cash',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'b57f13eb1d132cbc4ae1bbd2e6f89c5c1b1f90af',
#   'taxi_id': 'f3af8002f02eb5eea68aa4cba00200f124550bb4759054ac724120a004a60284071d87c838a0e12f8e403c3383fd4b5416739705ac06e5cd0e83ddf4e327300d',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '1125',
#   'trip_miles': '8.67',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '37',
#   'fare': '23.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '23.5',
#   'payment_type': 'Prcard',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.80908443',
#   'dropoff_centroid_longitude': '-87.632424524',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6324245245, 41.8090844303]}},
#  {'trip_id': 'b4aed1a43863e6fc419b3a146a7cb21a8da7e2f0',
#   'taxi_id': 'c4c426cd131fa75995a86433c4078631b49bce91149db71e7ef29c10a3702b978b3d305631720cbfe1b5f086bfaa23718885df7af7b7da91542a90c5d1f3f8bb',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1401',
#   'trip_miles': '3.9',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '24',
#   'fare': '15.25',
#   'tips': '3.35',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '20.1',
#   'payment_type': 'Mobile',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': 'b44bd407bc1b64102594f286a971a2d4779d50eb',
#   'taxi_id': '1a248eb87ae578f15af2a14c2eb7b4b264f6babab9ad9cc93d655e1f83c3207e62beb1a4b088d75e8077a5421391d32171edacfcb3f6250657f8d3b9f0ebbaec',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1471',
#   'trip_miles': '11.34',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '4',
#   'fare': '30',
#   'tips': '6.9',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '41.4',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.975170943',
#   'dropoff_centroid_longitude': '-87.687515515',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6875155152, 41.9751709433]}},
#  {'trip_id': 'ac367ebc97c869c7c4fb3d37076c11ac60bdc86e',
#   'taxi_id': 'd41e198fbed96bdbe8649a6c626cfeb16e5f82ca39a0c72bde5344a5166779475e0035d83523884b2e5d36ec55f91f94101f6e7c35bb3d056464c726614f1a81',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '554',
#   'trip_miles': '3.58',
#   'pickup_community_area': '76',
#   'fare': '11.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '16.75',
#   'payment_type': 'Cash',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'ab7aa3dc2f030c63d54a1cd35f6e9d1d6f32069d',
#   'taxi_id': '3c5b4f29aac78c145bf09a567d547e22ab95655e4288d93bb78ac65c87a6843c6cc87c02dadd0a8652f43c3206f416b11dd7e03bb438be1c5a176902f1afb742',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '1149',
#   'trip_miles': '14.6',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '7',
#   'fare': '36.5',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '43',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': 'ab64e362edeca889f4b08dbafcd9d0fd3d8f41d3',
#   'taxi_id': '32f4851c78cfd5e0e5665b5f3c56bfc6ed6ab31cf2798330452dea6c4117437f54ca608e6f50e5e87be10f40d1123bbef3d1a1ddf38ab8cae36e7089dd238d0b',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '703',
#   'trip_miles': '1.89',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '28',
#   'fare': '10',
#   'tips': '2.17',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12.17',
#   'payment_type': 'Mobile',
#   'company': 'Blue Ribbon Taxi Association',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': 'aa169f938745be8783ccbfe8f3b97b567a06ac39',
#   'taxi_id': '42560393a9c9b9ae28339f4b5aec77fd89bd49916ad54175d9ee679d69939f973c177065f2816d7990a6663a07270335a4a852190c3258497ba7978edced68c8',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '589',
#   'trip_miles': '1.49',
#   'pickup_census_tract': '17031280100',
#   'dropoff_census_tract': '17031081600',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '8.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '8.25',
#   'payment_type': 'Cash',
#   'company': 'Patriot Taxi Dba Peace Taxi Associat',
#   'pickup_centroid_latitude': '41.885300022',
#   'pickup_centroid_longitude': '-87.642808466',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6428084655, 41.8853000224]},
#   'dropoff_centroid_latitude': '41.892072635',
#   'dropoff_centroid_longitude': '-87.628874157',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6288741572, 41.8920726347]}},
#  {'trip_id': 'a72f7893c5aa23b9377fd89e91b1b553f4afbdb6',
#   'taxi_id': 'ae21d024a249783394ef3fcd91c8abad23fe127549fe964ac600cfa54a91bf42db12d9982b9d4b4b12b8f871e08d44811e99a54675bb1d2806716aaffaba3989',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '780',
#   'trip_miles': '0.2',
#   'pickup_community_area': '7',
#   'dropoff_community_area': '8',
#   'fare': '12.5',
#   'tips': '3.2',
#   'tolls': '0',
#   'extras': '3',
#   'trip_total': '18.7',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.922686284',
#   'pickup_centroid_longitude': '-87.649488729',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'a6f41809e8ee0ad805abb9d8e4980bd6a1a776d3',
#   'taxi_id': '04314cd00cdc5987ed8e77a1a69fc1f13d34916df96e14766f286a84540b2fd2146c9831b521fa7bfd619120355b5d589bfedab7a91d9e4876dba7ad91900fed',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '470',
#   'trip_miles': '0.2',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '24',
#   'fare': '13.87',
#   'tips': '3.74',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '17.61',
#   'payment_type': 'Mobile',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.901206994',
#   'dropoff_centroid_longitude': '-87.676355989',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]}},
#  {'trip_id': 'a34c245030dcc8fd25a3064658bad7ab10d263d9',
#   'taxi_id': 'f35fcc7d28fd3ca0324ad6b42c6bf1dd0413320a9c4b65cb10b92def1ea763bd2bd706f4e189be46b08d37e56f1ddb72f06d89e6a64e0cb7172e3618e519c33e',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '7',
#   'trip_miles': '0',
#   'fare': '47.5',
#   'tips': '12',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '60',
#   'payment_type': 'Credit Card',
#   'company': 'Medallion Leasin'},
#  {'trip_id': 'a042d021b80a116faebf99f7f6af083cb8f6740f',
#   'taxi_id': '58c784c628cc2b0b77468e6a406acea729301abbc17a6240eed68ac3b5ce5a9378deffab5b2b940db6c83e7c9553eacd8fdb8d10593e071cefffe2b388af3bd7',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '1011',
#   'trip_miles': '4.48',
#   'pickup_community_area': '22',
#   'dropoff_community_area': '8',
#   'fare': '16.22',
#   'tips': '4.35',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '20.57',
#   'payment_type': 'Mobile',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.92276062',
#   'pickup_centroid_longitude': '-87.699155343',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '9fb21cd4996f7c6a8cb7547d32e43590baf74efc',
#   'taxi_id': 'ea9c7f865233f880e5f00abb728092901eeaf52c85a8c1dc97f117e85dd7dfadd30a8d2f6f61d627e780a22bec39d98a24ea56e022d3b6b8501b182a933c9ca7',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:00:00.000',
#   'trip_seconds': '780',
#   'trip_miles': '5.7',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '3',
#   'fare': '17.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '18.5',
#   'payment_type': 'Cash',
#   'company': 'Choice Taxi Association',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.96581197',
#   'dropoff_centroid_longitude': '-87.655878786',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]}},
#  {'trip_id': '9ad2ede4853c16ec5696a52d920a2591af73235d',
#   'taxi_id': 'fbbd674a65df66aae44f5261b5be2ac0f6bd0abb247f837f51819c6df813a347eb0f34eaef14eaaf3e1a6be4feba5447eecce38a71fbcf3b9e037a63459c3fab',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-29T23:45:00.000',
#   'trip_seconds': '231',
#   'trip_miles': '0.85',
#   'pickup_community_area': '13',
#   'dropoff_community_area': '2',
#   'fare': '10',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '10',
#   'payment_type': 'Mobile',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.983636307',
#   'pickup_centroid_longitude': '-87.723583185',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7235831853, 41.9836363072]},
#   'dropoff_centroid_latitude': '42.001571027',
#   'dropoff_centroid_longitude': '-87.695012589',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6950125892, 42.001571027]}},
#  {'trip_id': '92f9dbf87bbca7310e990647a576887eae4962b7',
#   'taxi_id': '6436b1ea087d8dd1c5b6393c8c3331353195b37673bfa29193e13df48096dee0d000a539e29ae747b828e217e5332d50473ff67e4f8ec5fbae89504eaf36e1f2',
#   'trip_start_timestamp': '2024-06-29T23:45:00.000',
#   'trip_end_timestamp': '2024-06-30T00:15:00.000',
#   'trip_seconds': '1854',
#   'trip_miles': '17.3',
#   'pickup_community_area': '69',
#   'dropoff_community_area': '77',
#   'fare': '52.76',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '52.76',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.763246799',
# ...
#   'pickup_centroid_longitude': '-87.72345239',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7234523905, 41.9535821253]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': 'f66481068fb871df7d042caa0c53f39514696c52',
#   'taxi_id': '04657e62affd139b62541d8f0a874c44392d50f99fce5460d9e0a987011e39562b7a7784e2592f571608d1fd0183514c6d2ec6f08d0f8edd45c2402811c1149d',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:00:00.000',
#   'trip_seconds': '5',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031330100',
#   'dropoff_census_tract': '17031330100',
#   'pickup_community_area': '33',
#   'dropoff_community_area': '33',
#   'fare': '10',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.859349715',
#   'pickup_centroid_longitude': '-87.617358006',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6173580061, 41.859349715]},
#   'dropoff_centroid_latitude': '41.859349715',
#   'dropoff_centroid_longitude': '-87.617358006',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6173580061, 41.859349715]}},
#  {'trip_id': 'f4aada84c5a5fe5831bffc3188a3d65ce2d34612',
#   'taxi_id': 'b3ee94a13b61037620cbbfc6a4a106d2ad628a06f0988f1eba5586d5387776d3781d71244392ff9c1afd5b69e65dfec45b2a936c2d101209044ff6365121ed6f',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:00:00.000',
#   'trip_seconds': '300',
#   'trip_miles': '0.6',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '5.25',
#   'tips': '3',
#   'tolls': '0',
#   'extras': '2',
#   'trip_total': '10.25',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'f2f59d56575de895a2a38ab01f9933610fe4e1d1',
#   'taxi_id': '4b07fb03bc0cc588c12cc0c764cdcfdaeb405f944f52111c9df9802b0658a0cde04c07c21d578875667dae2480606035e3c4b3e20f0bf6a16996afb2706a26d1',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:15:00.000',
#   'trip_seconds': '1260',
#   'trip_miles': '4.7',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '6',
#   'fare': '16.75',
#   'tips': '4.55',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '22.3',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': 'f14bdab4099fbf6664966e1a445bd05adbc0715e',
#   'taxi_id': '12bfcfb8715a63cacb9a4bc127f622071bab27b36a8488cbeccd3b5698b3f8ea9292662b3468f8d4668f1b84f5a96d8fd4436522abad8b8994c7ad40309a1805',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:30:00.000',
#   'trip_seconds': '1421',
#   'trip_miles': '7.27',
#   'pickup_community_area': '49',
#   'dropoff_community_area': '42',
#   'fare': '23',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '23',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.706587882',
#   'pickup_centroid_longitude': '-87.623366512',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6233665115, 41.7065878819]},
#   'dropoff_centroid_latitude': '41.77887686',
#   'dropoff_centroid_longitude': '-87.594925439',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5949254391, 41.7788768603]}},
#  {'trip_id': 'f144b9e9b6ba71951b9c1c327f9731853064084d',
#   'taxi_id': '0100a31447467f038f7ecd2addffc048bec8fe8cf1d8c9eafb360c6342c3c8f4aee0069d44da82207873e81ac0cee8fea124cf3cd0a95127fa0092de44ecb50b',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:00:00.000',
#   'trip_seconds': '660',
#   'trip_miles': '6.3',
#   'pickup_community_area': '76',
#   'fare': '17.5',
#   'tips': '1',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '23.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency, LLC',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'f13be9dc161b22448a21278d104fe160b4041128',
#   'taxi_id': '63081d550846f1e0c56209bb972eb0fe5b92f5b8c86a135943b6f411ce62b194533962e2047e07f44b68399fb61622c4a4e3af621f5f89e4382aa4343038052d',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:45:00.000',
#   'trip_seconds': '3360',
#   'trip_miles': '20.9',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320400',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '54.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '59.25',
#   'payment_type': 'Cash',
#   'company': '312 Medallion Management Corp',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.877406123',
#   'dropoff_centroid_longitude': '-87.621971652',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6219716519, 41.8774061234]}},
#  {'trip_id': 'efc9760ade5ffc92caef393ac993150010352a91',
#   'taxi_id': '214fcdd082c941bd6273631b0ff3cedc4bd5307f719e731b7c2c87f3fc956631333f8deefb6093275c5e628b20d631651e835f4eb4d1387498be140030749f32',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:00:00.000',
#   'trip_seconds': '699',
#   'trip_miles': '3.45',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '76',
#   'fare': '12.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '6.5',
#   'trip_total': '18.75',
#   'payment_type': 'Cash',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.97907082',
#   'dropoff_centroid_longitude': '-87.903039661',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': 'ec4752ab3c3525de0ce1ca25643efadca93a716a',
#   'taxi_id': '4b521ee042b8ac4785c2740c26ae75a039961139e63b3a9cdffa28505045ad7401a600a508cb32670c86944f93ec498cab35c813b6f4b61f82c3bbbf82f002e1',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:15:00.000',
#   'trip_seconds': '570',
#   'trip_miles': '2.93',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031770700',
#   'pickup_community_area': '76',
#   'fare': '10.75',
#   'tips': '3.05',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '18.3',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.982775009',
#   'dropoff_centroid_longitude': '-87.8773054',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.8773053996, 41.9827750091]}},
#  {'trip_id': 'eba75d24a49e3ed9aba419b52c2c888f29d7dd2d',
#   'taxi_id': '131107e9f0f51399bdc9e8c2eb94fce500bdf22daeb1f87481182334da2c0e8a041ddfcd898a1fb5cc4227d028328db1cc13d0d08cb3f4a020c47bddd5840d7e',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:15:00.000',
#   'trip_seconds': '326',
#   'trip_miles': '0.99',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '28',
#   'fare': '9',
#   'tips': '1.73',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '10.73',
#   'payment_type': 'Mobile',
#   'company': 'Tac - Checker Cab Dispatch',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': 'ea5ae3ca58acfc8312bdaf0f30c9c25050ae90da',
#   'taxi_id': '52a94e237e6ca1f7e21267d6b906e3abaec95d6f057632cb15de057c45f3a4563223364dbf44dbde94f7b8d65d7b193a7d4e260b58f3931b3f98078e9f24aa9f',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:15:00.000',
#   'trip_seconds': '1320',
#   'trip_miles': '10.3',
#   'pickup_community_area': '39',
#   'dropoff_community_area': '6',
#   'fare': '27.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '27.75',
#   'payment_type': 'Unknown',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.808916283',
#   'pickup_centroid_longitude': '-87.596183344',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5961833442, 41.8089162826]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  {'trip_id': 'e99287323c3e7f98ac13266b2c719f7bf408b48f',
#   'taxi_id': '8193e58ab16cb38a3f58b187b3c836539baed5a2afb9bc27b64f06ab4d7ce20da73fda35529894218f64746f5305558c5ad77f229c3913fd442bf915880d2b76',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:15:00.000',
#   'trip_seconds': '1062',
#   'trip_miles': '9.3',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '15',
#   'fare': '24.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5.5',
#   'trip_total': '30',
#   'payment_type': 'Cash',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.954027649',
#   'dropoff_centroid_longitude': '-87.763399032',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7633990316, 41.9540276487]}},
#  {'trip_id': 'e9372c21f9a1f63cf8b887c6791c8bb822ec9366',
#   'taxi_id': '1a6d17595bc577385346e034ecbe0994d8f207d47d5b4c6f9fee70a1d4f37417db300370d59596dc2dd0bda2e35794bcdfd1bbead90d84a44aedd978ed269944',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:30:00.000',
#   'trip_seconds': '1775',
#   'trip_miles': '6.68',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '3',
#   'fare': '22.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '23.25',
#   'payment_type': 'Cash',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.96581197',
#   'dropoff_centroid_longitude': '-87.655878786',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]}},
#  {'trip_id': 'e908725a6e2a2ba0dd3d058942f90f09c1567537',
#   'taxi_id': '2f4e29a2c83f6b9c2b8ce735865fdddf49627f8d60bbfff69690a9839eb165a7615a2eed186208d8010288e533e6416eb5506d4619067b8754fd9664217c9eb0',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:45:00.000',
#   'trip_seconds': '2581',
#   'trip_miles': '11.2',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '2',
#   'fare': '33.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '34.25',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '42.001571027',
#   'dropoff_centroid_longitude': '-87.695012589',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6950125892, 42.001571027]}},
#  {'trip_id': 'e493b1f83dab8c671df56c91d7d6e71669d941a0',
#   'taxi_id': 'fc0c7db172c81d1a2ab72cc31b27f4917d40ee8d0a43d66c5fdd0600457168f7c8728a9a9ebdc30102d5c663f45458bc53fb0fcdcae87254fffd99642a8eb921',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:15:00.000',
#   'trip_seconds': '1179',
#   'trip_miles': '3.18',
#   'pickup_community_area': '7',
#   'dropoff_community_area': '32',
#   'fare': '13.66',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '13.66',
#   'payment_type': 'Mobile',
#   'company': 'Tac - Yellow Cab Association',
#   'pickup_centroid_latitude': '41.922686284',
#   'pickup_centroid_longitude': '-87.649488729',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'dd089c5262afc9288db44431d52c86f0a7def1b9',
#   'taxi_id': 'dff8b2296e1abd3c3470a2f0765b3f385f9a53c8df1cc314e899a81be2cfb6f52c61af660e6434c35e2c1a4ab2eeb004ab0027826471be4fff9a4648ef51e7a0',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:00:00.000',
#   'trip_seconds': '523',
#   'trip_miles': '1.21',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '28',
#   'fare': '9',
#   'tips': '2.3',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.3',
#   'payment_type': 'Mobile',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': 'db9ffa61aed27328576fa1840915f692e287c907',
#   'taxi_id': '0ed96f11414297581014df319b690503d335ba479b8d578fc4ce5ee12067eb1ed16d13487c2c56391bc82fd284934a528a98a92a8ba231607a38826a7c03c3e5',
#   'trip_start_timestamp': '2024-06-29T22:00:00.000',
#   'trip_end_timestamp': '2024-06-29T22:15:00.000',
#   'trip_seconds': '1560',
#   'trip_miles': '16.2',
#   'pickup_census_tract': '17031839100',
#   'dropoff_census_tract': '17031770700',
#   'pickup_community_area': '32',
#   'fare': '40.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '40.75',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.880994471',
#   'pickup_centroid_longitude': '-87.632746489',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]},
#   'dropoff_centroid_latitude': '41.982775009',
#   'dropoff_centroid_longitude': '-87.8773054',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.8773053996, 41.9827750091]}},
#  ...]
